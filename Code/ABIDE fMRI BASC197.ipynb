# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from nilearn.datasets import fetch_abide_pcp
# Fetch the full data and update phenotypic data and cross_validation
abide = fetch_abide_pcp(derivatives = ['func_preproc'], pipeline = 'cpac', quality_checked = True)
y = abide.phenotypic['DX_GROUP']
y[y == 2] = 0
atlas = 'BASC197'

# %% [markdown]
# # Retrieving multiscale group brain parcellations

# %%
# import datasets module and use `fetch_atlas_basc_multiscale_2015` function
from nilearn import datasets
parcellations = datasets.fetch_atlas_basc_multiscale_2015(version='sym')

# %%
# We show here networks of 64, 197, 444
networks_64 = parcellations['scale064']
networks_197 = parcellations['scale197']
networks_444 = parcellations['scale444']

# %%
from nilearn.input_data import NiftiLabelsMasker
masker = NiftiLabelsMasker(networks_197,
                           memory='nilearn_cache',
                           memory_level=1,
                           smoothing_fwhm=6,
                           detrend=True,
                           verbose=1)

# %%
time_series_basc197 = []
for i in range(len(abide.func_preproc)):
    time_series_basc197.append(masker.fit_transform(abide.func_preproc[i]))
# Out:
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# Resampling labels
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050003_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E86011D4F0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050003_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050004_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E8600CA130>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050004_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 6.0s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050005_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E8600CA130>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050005_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050006_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85FB18EB0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050006_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050007_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85F89B070>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050007_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050008_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85F89B070>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050008_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050010_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85F89B070>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050010_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050011_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85F89B070>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050011_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050012_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E8615B8100>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050012_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050013_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E861489640>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050013_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050014_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85F89B070>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050014_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050015_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E861489640>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050015_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050016_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85CD14970>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050016_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050020_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E861489640>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050020_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050022_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85FB18EB0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050022_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050023_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85CD148E0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050023_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050024_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85FB18EB0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050024_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050025_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85F89B070>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050025_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050026_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E8600E5E80>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050026_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050027_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85CD14970>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050027_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050028_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85FB18EB0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050028_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050030_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E8600E5EB0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050030_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050031_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85FB18EB0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050031_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050032_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E861489640>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050032_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050033_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E861489640>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050033_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050034_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E8600E5EB0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050034_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050035_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E8600E5EB0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050035_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050036_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E8600CA130>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050036_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050037_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85F89B070>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050037_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050038_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85F89B070>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050038_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050039_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85F89B070>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050039_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\Pitt_0050040_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E8600E5EB0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
# ...
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051576_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\SBL_0051577_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85CD02040>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051577_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\SBL_0051578_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85F8975B0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051578_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\SBL_0051579_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85CD14970>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051579_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\SBL_0051580_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85CD02040>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051580_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\SBL_0051582_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85F897FA0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051582_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\SBL_0051583_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85CD02040>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051583_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\SBL_0051584_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85CD14970>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051584_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.8s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\SBL_0051585_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E85CD02040>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051585_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 5.9s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\MaxMun_a_0051606_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E8615B8160>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\MaxMun_a_0051606_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.4s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from C:\Users\xyang/nilearn_data\basc_multiscale_2015\template_cambridge_basc_multiscale_nii_sym\template_cambridge_basc_multiscale_sym_scale197.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('C:\\Users\\xyang/nilearn_data\\ABIDE_pcp\\cpac\\nofilt_noglobal\\MaxMun_a_0051607_func_preproc.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x000001E8615B8160>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': 'C:\\Users\\xyang/nilearn_data\\basc_multiscale_2015\\template_cambridge_basc_multiscale_nii_sym\\template_cambridge_basc_multiscale_sym_scale197.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6,
#   'standardize': False,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\MaxMun_a_0051607_func_preproc.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 3.4s, 0.1min

# %%
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score, recall_score
scoring = {
    'accuracy':    make_scorer(accuracy_score),
    'sensitivity': make_scorer(recall_score),
    'specificity': make_scorer(recall_score,pos_label=0)
}

# %%
correlation = 'correlation'
partial = 'partial correlation'
tangent = 'tangent'

lr = "LR"
lsvm = "LSVM"
ksvm = "kSVM"
rf = "RF"
ab = "AB"


measure = [correlation, partial, tangent]

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression

lr_corr = LogisticRegression(C = 0.01)
lr_part = LogisticRegression(C = 1)
lr_tang = LogisticRegression(C = 1)

# %%
# Linear SVM
from sklearn.svm import SVC

lsvm_corr = SVC(kernel='linear',C = 0.01)
lsvm_part = SVC(kernel='linear',C = 0.1)
lsvm_tang = SVC(kernel='linear',C = 0.01)

# %%
# Kernel SVM

ksvm_corr = SVC(gamma = 'auto', C = 100)
ksvm_part = SVC(gamma = 'auto', C = 1000)
ksvm_tang = SVC(gamma = 'auto', C = 100)

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

rf_corr = RandomForestClassifier(max_depth = 8, random_state = 0)
rf_part = RandomForestClassifier(max_depth = 8, random_state = 0)
rf_tang = RandomForestClassifier(max_depth = 6, random_state = 0)

# %%
# Adaboost
from sklearn.ensemble import AdaBoostClassifier

ab_corr = AdaBoostClassifier(n_estimators = 100)
ab_part = AdaBoostClassifier(n_estimators = 100)
ab_tang = AdaBoostClassifier(n_estimators = 100)

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 0)

# %% [markdown]
# =========================================================
# # Logistic Regression
# =========================================================

# %% [markdown]
# #### Kind = Correlation, Partial Correlation, Tangent
# ===========================================================================================================

# %%
# Correlation
from crossvalidation import CrossValidation

[X_lr_corr, lr_corr_scores] = CrossValidation(lr_corr, correlation, y, skf, time_series_basc197)
[X_lr_part, lr_part_scores] = CrossValidation(lr_part, partial,     y, skf, time_series_basc197)
[X_lr_tang, lr_tang_scores] = CrossValidation(lr_tang, tangent,     y, skf, time_series_basc197)

# %%
from scores import getScores
[lr_corr_acc, lr_corr_sen, lr_corr_spe] = getScores(lr_corr_scores)
[lr_part_acc, lr_part_sen, lr_part_spe] = getScores(lr_part_scores)
[lr_tant_acc, lr_tang_sen, lr_tang_spe] = getScores(lr_tang_scores)

# %% [markdown]
# ##### Receiver Operating Characteristic (ROC) with cross validation
# ======================================================================================================

# %%
from roc import plotROC

# %%
import matplotlib.pylab as pl

plotROC(lr_corr, X_lr_corr, y, skf, atlas, correlation, lr)
plotROC(lr_part, X_lr_part, y, skf, atlas, partial, lr)
plotROC(lr_tang, X_lr_tang, y, skf, atlas, tangent, lr)

# %% [markdown]
# =========================================================
# # Linear SVM
# =========================================================

# %% [markdown]
# #### Kind = Correlation, Partial Correlation, Tangent
# ===========================================================================================================

# %%
# Correlation
from crossvalidation import CrossValidation

[X_lsvm_corr, lsvm_corr_scores] = CrossValidation(lsvm_corr, correlation, y, skf, time_series_basc197)
[X_lsvm_part, lsvm_part_scores] = CrossValidation(lsvm_part, partial,     y, skf, time_series_basc197)
[X_lsvm_tang, lsvm_tang_scores] = CrossValidation(lsvm_tang, tangent,     y, skf, time_series_basc197)

# %%
from scores import getScores
[lsvm_corr_acc, lsvm_corr_sen, lsvm_corr_spe] = getScores(lsvm_corr_scores)
[lsvm_part_acc, lsvm_part_sen, lsvm_part_spe] = getScores(lsvm_part_scores)
[lsvm_tant_acc, lsvm_tang_sen, lsvm_tang_spe] = getScores(lsvm_tang_scores)

# %% [markdown]
# ##### Receiver Operating Characteristic (ROC) with cross validation
# ======================================================================================================

# %%
from roc import plotROC

import matplotlib.pylab as pl

plotROC(lsvm_corr, X_lsvm_corr, y, skf, atlas, correlation, lsvm)
plotROC(lsvm_part, X_lsvm_part, y, skf, atlas, partial, lsvm)
plotROC(lsvm_tang, X_lsvm_tang, y, skf, atlas, tangent, lsvm)

# %% [markdown]
# =========================================================
# # Kernal SVM
# =========================================================

# %% [markdown]
# #### Kind = Correlation, Partial Correlation, Tangent
# ===========================================================================================================

# %%
# Correlation
from crossvalidation import CrossValidation

[X_ksvm_corr, ksvm_corr_scores] = CrossValidation(ksvm_corr, correlation, y, skf, time_series_basc197)
[X_ksvm_part, ksvm_part_scores] = CrossValidation(ksvm_part, partial,     y, skf, time_series_basc197)
[X_ksvm_tang, ksvm_tang_scores] = CrossValidation(ksvm_tang, tangent,     y, skf, time_series_basc197)

# %%
from scores import getScores
[ksvm_corr_acc, ksvm_corr_sen, ksvm_corr_spe] = getScores(ksvm_corr_scores)
[ksvm_part_acc, ksvm_part_sen, ksvm_part_spe] = getScores(ksvm_part_scores)
[ksvm_tant_acc, ksvm_tang_sen, ksvm_tang_spe] = getScores(ksvm_tang_scores)

# %% [markdown]
# ##### Receiver Operating Characteristic (ROC) with cross validation
# ======================================================================================================

# %%
from roc import plotROC

import matplotlib.pylab as pl

plotROC(ksvm_corr, X_ksvm_corr, y, skf, atlas, correlation, ksvm)
plotROC(ksvm_part, X_ksvm_part, y, skf, atlas, partial, ksvm)
plotROC(ksvm_tang, X_ksvm_tang, y, skf, atlas, tangent, ksvm)

# %% [markdown]
# =========================================================
# # Random Forest
# =========================================================

# %% [markdown]
# #### Kind = Correlation, Partial Correlation, Tangent
# ===========================================================================================================

# %%
# Correlation
from crossvalidation import CrossValidation

[X_rf_corr, rf_corr_scores] = CrossValidation(rf_corr, correlation, y, skf, time_series_basc197)
[X_rf_part, rf_part_scores] = CrossValidation(rf_part, partial,     y, skf, time_series_basc197)
[X_rf_tang, rf_tang_scores] = CrossValidation(rf_tang, tangent,     y, skf, time_series_basc197)

# %%
from scores import getScores
[rf_corr_acc, rf_corr_sen, rf_corr_spe] = getScores(rf_corr_scores)
[rf_part_acc, rf_part_sen, rf_part_spe] = getScores(rf_part_scores)
[rf_tant_acc, rf_tang_sen, rf_tang_spe] = getScores(rf_tang_scores)

# %% [markdown]
# ##### Receiver Operating Characteristic (ROC) with cross validation
# ======================================================================================================

# %%
from roc import plotROC

import matplotlib.pylab as pl

plotROC(rf_corr, X_rf_corr, y, skf, atlas, correlation, rf)
plotROC(rf_part, X_rf_part, y, skf, atlas, partial, rf)
plotROC(rf_tang, X_rf_tang, y, skf, atlas, tangent, rf)

# %% [markdown]
# =========================================================
# # Ada Boost
# =========================================================

# %% [markdown]
# #### Kind = Correlation, Partial Correlation, Tangent
# ===========================================================================================================

# %%
# Correlation
from crossvalidation import CrossValidation

[X_ab_corr, ab_corr_scores] = CrossValidation(ab_corr, correlation, y, skf, time_series_basc197)
[X_ab_part, ab_part_scores] = CrossValidation(ab_part, partial,     y, skf, time_series_basc197)
[X_ab_tang, ab_tang_scores] = CrossValidation(ab_tang, tangent,     y, skf, time_series_basc197)

# %%
from scores import getScores
[ab_corr_acc, ab_corr_sen, ab_corr_spe] = getScores(ab_corr_scores)
[ab_part_acc, ab_part_sen, ab_part_spe] = getScores(ab_part_scores)
[ab_tant_acc, ab_tang_sen, ab_tang_spe] = getScores(ab_tang_scores)

# %% [markdown]
# ##### Receiver Operating Characteristic (ROC) with cross validation
# ======================================================================================================

# %%
from roc import plotROC

import matplotlib.pylab as pl

plotROC(ab_corr, X_ab_corr, y, skf, atlas, correlation, ab)
plotROC(ab_part, X_ab_part, y, skf, atlas, partial, ab)
plotROC(ab_tang, X_ab_tang, y, skf, atlas, tangent, ab)

# %% [markdown]
# # Summary Results

# %%
from IPython.display import HTML, display

test=[["","","Correlation"," "," ","Parital Corr",""," ","Tangent",""],
      
      ["Classifier","Sensitivity","Specificity", "Accuracy",\
       "Sensitivity","Specificity", "Accuracy",\
       "Sensitivity","Specificity", "Accuracy"],
      
      ["LR",lr_corr_sen,lr_corr_spe,lr_corr_acc,\
       lr_part_sen,lr_part_spe,lr_part_acc,\
       lr_tang_sen,lr_tang_spe,lr_tant_acc
      ],
      
      ["lSVM",lsvm_corr_sen,lsvm_corr_spe,lsvm_corr_acc,\
       lsvm_part_sen,lsvm_part_spe,lsvm_part_acc,\
       lsvm_tang_sen,lsvm_tang_spe,lsvm_tant_acc
      ],
      
      ["kSVM",ksvm_corr_sen,ksvm_corr_spe,ksvm_corr_acc,\
       ksvm_part_sen,ksvm_part_spe,ksvm_part_acc,\
       ksvm_tang_sen,ksvm_tang_spe,ksvm_tant_acc
      ],
      
      ["RF",rf_corr_sen,rf_corr_spe,rf_corr_acc,\
       rf_part_sen,rf_part_spe,rf_part_acc,\
       rf_tang_sen,rf_tang_spe,rf_tant_acc
      ], 
      
      ["AB",ab_corr_sen,ab_corr_spe,ab_corr_acc,\
       ab_part_sen,ab_part_spe,ab_part_acc,\
       ab_tang_sen,ab_tang_spe,ab_tant_acc
      ]
     ]

print("Test:")
print("===========================================================================================")
display(HTML(
   '<table><tr>{}</tr></table>'.format(
       '</tr><tr>'.join(
           '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row)) for row in test))
))
# Out:
# Test:
# ===========================================================================================
# <table><tr><td></td><td></td><td>Correlation</td><td> </td><td> </td><td>Parital Corr</td><td></td><td> </td><td>Tangent</td><td></td></tr><tr><td>Classifier</td><td>Sensitivity</td><td>Specificity</td><td>Accuracy</td><td>Sensitivity</td><td>Specificity</td><td>Accuracy</td><td>Sensitivity</td><td>Specificity</td><td>Accuracy</td></tr><tr><td>LR</td><td>62.04%</td><td>73.08%</td><td>67.97%</td><td>48.40%</td><td>75.64%</td><td>63.04%</td><td>60.06%</td><td>75.63%</td><td>68.43%</td></tr><tr><td>lSVM</td><td>64.28%</td><td>71.79%</td><td>68.31%</td><td>52.61%</td><td>71.16%</td><td>62.58%</td><td>61.80%</td><td>76.27%</td><td>69.58%</td></tr><tr><td>kSVM</td><td>63.04%</td><td>70.94%</td><td>67.28%</td><td>52.61%</td><td>71.37%</td><td>62.69%</td><td>62.79%</td><td>76.05%</td><td>69.92%</td></tr><tr><td>RF</td><td>42.45%</td><td>76.90%</td><td>60.96%</td><td>26.56%</td><td>80.13%</td><td>55.34%</td><td>23.58%</td><td>80.78%</td><td>54.31%</td></tr><tr><td>AB</td><td>56.08%</td><td>63.67%</td><td>60.16%</td><td>52.12%</td><td>56.41%</td><td>54.41%</td><td>53.12%</td><td>61.97%</td><td>57.87%</td></tr></table>
