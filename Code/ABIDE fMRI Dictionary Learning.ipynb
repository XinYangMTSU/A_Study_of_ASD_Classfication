# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from nilearn.datasets import fetch_abide_pcp
# Fetch the full data and update phenotypic data and cross_validation
abide = fetch_abide_pcp(derivatives = ['func_preproc'], pipeline = 'cpac', quality_checked = True)
y = abide.phenotypic['DX_GROUP']
y[y == 2] = 0
atlas = 'Dict'
# Out:
# C:\Users\xyang\Anaconda3\lib\site-packages\numpy\lib\npyio.py:2372: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   output = genfromtxt(fname, **kwargs)

# %% [markdown]
# # Apply Diction Leanring on the data

# %%
from nilearn.decomposition import DictLearning

dict_learning = DictLearning(n_components=20,
                             memory="nilearn_cache", memory_level=2,
                             verbose=1,
                             random_state=0,
                             n_epochs=1,
                             mask_strategy='template')

dict_learning.fit(abide.func_preproc)

# Retrieve the independent components in brain space. Directly
# accesible through attribute `components_img_`.
dict_learning_img = dict_learning.components_img_
# Out:
# [MultiNiftiMasker.fit] Loading data from [C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050003_func_preproc.nii.gz, C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050004_func_preproc.nii.gz, C:\Users\xyan
# [MultiNiftiMasker.fit] Computing mask
# [MultiNiftiMasker.transform] Resampling mask
# [DictLearning] Loading data
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050003_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050004_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050005_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050006_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050007_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050008_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050010_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050011_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050012_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050013_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050014_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050015_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050016_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050020_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050022_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050023_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050024_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050025_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050026_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050027_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050028_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050030_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050031_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050032_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050033_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050034_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050035_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050036_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050037_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050038_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050039_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050040_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050041_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050042_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050043_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050044_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050045_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050046_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050047_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050048_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050049_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050050_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050051_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050052_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050053_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050054_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050056_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050057_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050059_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Pitt_0050060_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050102_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050103_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050104_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050105_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050106_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050107_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050109_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050111_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050112_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050113_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050114_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050115_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050116_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050117_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050118_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050119_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050121_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050123_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050124_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050125_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050127_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050128_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050129_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050130_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050131_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050132_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050134_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Olin_0050135_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050142_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050143_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050144_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050145_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050146_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050147_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050148_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050149_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050150_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050152_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050153_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050156_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050157_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050158_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050159_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050160_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050161_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050162_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050163_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050164_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050167_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050168_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050169_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050170_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\OHSU_0050171_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050182_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050183_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050184_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050186_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050187_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050188_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050189_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050190_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050193_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050194_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050195_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050196_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050198_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050199_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050200_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050201_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050202_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050203_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050204_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050205_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050206_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050208_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050210_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050213_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050214_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050215_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SDSU_0050217_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Trinity_0050232_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Trinity_0050233_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Trinity_0050234_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# ...
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Caltech_0051481_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Caltech_0051482_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Caltech_0051484_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Caltech_0051487_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Caltech_0051488_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Caltech_0051491_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\Caltech_0051493_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051556_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051557_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051558_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051559_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051560_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051562_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051563_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051564_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051565_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051566_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051567_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051568_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051569_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051570_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051572_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051573_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051574_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051576_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051577_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051578_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051579_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051580_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051582_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051583_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051584_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\SBL_0051585_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\MaxMun_a_0051606_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [MultiNiftiMasker.transform_single_imgs] Loading data from Nifti1Image('C:\Users\xyang/nilearn_data\ABIDE_pcp\cpac\nofilt_noglobal\MaxMun_a_0051607_func_preproc.nii.gz')
# [MultiNiftiMasker.transform_single_imgs] Smoothing images
# [MultiNiftiMasker.transform_single_imgs] Extracting region signals
# [MultiNiftiMasker.transform_single_imgs] Cleaning extracted signals
# [DictLearning] Learning initial components
# ________________________________________________________________________________
# [Memory] Calling sklearn.utils.extmath.randomized_svd...
# randomized_svd(array([[ 0.005957, ..., -0.00234 ],
#        ...,
#        [ 0.006441, ...,  0.008856]]), n_components=20, transpose=True, random_state=0, n_iter=3)
# __________________________________________________randomized_svd - 14.3s, 0.2min
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[0.003844, ..., 0.000627],
#        ...,
#        [0.003903, ..., 0.00037 ]]), whiten=True, fun='cube', random_state=209652396)
# __________________________________________________________fastica - 0.6s, 0.0min
# [DictLearning] Computing initial loadings
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s finished
# ________________________________________________________________________________
# [Memory] Calling nilearn.decomposition.dict_learning._compute_loadings...
# _compute_loadings(array([[-0.001082, ...,  0.002412],
#        ...,
#        [-0.003147, ..., -0.000135]]),
# array([[ 7.344229, ...,  7.941231],
#        ...,
#        [-0.699763, ...,  2.648199]]))
# C:\Users\xyang\Anaconda3\lib\site-packages\nilearn\decomposition\dict_learning.py:232: UserWarning: Persisting input arguments took 10.22s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   self.loadings_init_ = self._cache(_compute_loadings)(
# ________________________________________________compute_loadings - 11.8s, 0.2min
# [DictLearning] Learning dictionary
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._dict_learning.dict_learning_online...
# dict_learning_online(array([[ 7.344229, ..., -0.699763],
#        ...,
#        [ 7.941231, ...,  2.648199]]),
# 20, alpha=10, n_iter=3392, batch_size=20, method='cd', dict_init=array([[0.104555, ..., 0.265861],
#        ...,
#        [0.413863, ..., 0.193561]]), verbose=0, random_state=0, return_code=True, shuffle=True, n_jobs=1)
# C:\Users\xyang\Anaconda3\lib\site-packages\nilearn\decomposition\dict_learning.py:259: UserWarning: Persisting input arguments took 10.14s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   self.components_, _ = self._cache(dict_learning_online)(
# ____________________________________________dict_learning_online - 60.8s, 1.0min

# %%
# Each region index is stored in index_
from nilearn.regions import RegionExtractor

extractor = RegionExtractor(dict_learning_img, threshold=0.5,
                            thresholding_strategy='ratio_n_voxels',
                            extractor='local_regions',
                            standardize=True, min_region_size=1350)
# Just call fit() to process for regions extraction
extractor.fit()
# Extracted regions are stored in regions_img_
regions_extracted_img = extractor.regions_img_
# Each region index is stored in index_
regions_index = extractor.index_
# Total number of regions extracted
n_regions_extracted = regions_extracted_img.shape[-1]

# %%
# Region Extraction with Group ICA maps

# %%
from nilearn.connectome import ConnectivityMeasure

time_series_dict = []

for i in range(len(abide.func_preproc)):
    print("i: " + str(i))
    # call transform from RegionExtractor object to extract timeseries signals
    subject = extractor.transform(abide.func_preproc[i])
    # saving each subject correlation to correlations
    time_series_dict.append(subject)
# Out:
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# i: 10
# i: 11
# i: 12
# i: 13
# i: 14
# i: 15
# i: 16
# i: 17
# i: 18
# i: 19
# i: 20
# i: 21
# i: 22
# i: 23
# i: 24
# i: 25
# i: 26
# i: 27
# i: 28
# i: 29
# i: 30
# i: 31
# i: 32
# i: 33
# i: 34
# i: 35
# i: 36
# i: 37
# i: 38
# i: 39
# i: 40
# i: 41
# i: 42
# i: 43
# i: 44
# i: 45
# i: 46
# i: 47
# i: 48
# i: 49
# i: 50
# i: 51
# i: 52
# i: 53
# i: 54
# i: 55
# i: 56
# i: 57
# i: 58
# i: 59
# i: 60
# i: 61
# i: 62
# i: 63
# i: 64
# i: 65
# i: 66
# i: 67
# i: 68
# i: 69
# i: 70
# i: 71
# i: 72
# i: 73
# i: 74
# i: 75
# i: 76
# %%
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score, recall_score
scoring = {
    'accuracy':    make_scorer(accuracy_score),
    'sensitivity': make_scorer(recall_score),
    'specificity': make_scorer(recall_score,pos_label=0)
}

# %%
correlation = 'correlation'
partial = 'partial correlation'
tangent = 'tangent'

lr = "LR"
lsvm = "LSVM"
ksvm = "kSVM"
rf = "RF"
ab = "AB"


measure = [correlation, partial, tangent]

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression

lr_corr = LogisticRegression(C = 0.01)
lr_part = LogisticRegression(C = 1)
lr_tang = LogisticRegression(C = 1)

# %%
# Linear SVM
from sklearn.svm import SVC

lsvm_corr = SVC(kernel='linear',C = 0.01)
lsvm_part = SVC(kernel='linear',C = 0.1)
lsvm_tang = SVC(kernel='linear',C = 0.01)

# %%
# Kernel SVM

ksvm_corr = SVC(gamma = 'auto', C = 100)
ksvm_part = SVC(gamma = 'auto', C = 1000)
ksvm_tang = SVC(gamma = 'auto', C = 100)

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

rf_corr = RandomForestClassifier(max_depth = 8, random_state = 0)
rf_part = RandomForestClassifier(max_depth = 8, random_state = 0)
rf_tang = RandomForestClassifier(max_depth = 6, random_state = 0)

# %%
# Adaboost
from sklearn.ensemble import AdaBoostClassifier

ab_corr = AdaBoostClassifier(n_estimators = 100)
ab_part = AdaBoostClassifier(n_estimators = 100)
ab_tang = AdaBoostClassifier(n_estimators = 100)

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 0)

# %% [markdown]
# =========================================================
# # Logistic Regression
# =========================================================

# %% [markdown]
# #### Kind = Correlation, Partial Correlation, Tangent
# ===========================================================================================================

# %%
# Correlation
from crossvalidation import CrossValidation

[X_lr_corr, lr_corr_scores] = CrossValidation(lr_corr, correlation, y, skf, time_series_dict)
[X_lr_part, lr_part_scores] = CrossValidation(lr_part, partial,     y, skf, time_series_dict)
[X_lr_tang, lr_tang_scores] = CrossValidation(lr_tang, tangent,     y, skf, time_series_dict)
# Out:
# C:\Users\xyang\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\xyang\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\xyang\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\xyang\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\xyang\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from scores import getScores
[lr_corr_acc, lr_corr_sen, lr_corr_spe] = getScores(lr_corr_scores)
[lr_part_acc, lr_part_sen, lr_part_spe] = getScores(lr_part_scores)
[lr_tant_acc, lr_tang_sen, lr_tang_spe] = getScores(lr_tang_scores)

# %% [markdown]
# ##### Receiver Operating Characteristic (ROC) with cross validation
# ======================================================================================================

# %%
from roc import plotROC

# %%
import matplotlib.pylab as pl

plotROC(lr_corr, X_lr_corr, y, skf, atlas, correlation, lr)
plotROC(lr_part, X_lr_part, y, skf, atlas, partial, lr)
plotROC(lr_tang, X_lr_tang, y, skf, atlas, tangent, lr)
# Out:
# C:\Users\xyang\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\xyang\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\xyang\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\xyang\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\xyang\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# =========================================================
# # Linear SVM
# =========================================================

# %% [markdown]
# #### Kind = Correlation, Partial Correlation, Tangent
# ===========================================================================================================

# %%
# Correlation
from crossvalidation import CrossValidation

[X_lsvm_corr, lsvm_corr_scores] = CrossValidation(lsvm_corr, correlation, y, skf, time_series_dict)
[X_lsvm_part, lsvm_part_scores] = CrossValidation(lsvm_part, partial,     y, skf, time_series_dict)
[X_lsvm_tang, lsvm_tang_scores] = CrossValidation(lsvm_tang, tangent,     y, skf, time_series_dict)

# %%
from scores import getScores
[lsvm_corr_acc, lsvm_corr_sen, lsvm_corr_spe] = getScores(lsvm_corr_scores)
[lsvm_part_acc, lsvm_part_sen, lsvm_part_spe] = getScores(lsvm_part_scores)
[lsvm_tant_acc, lsvm_tang_sen, lsvm_tang_spe] = getScores(lsvm_tang_scores)

# %% [markdown]
# ##### Receiver Operating Characteristic (ROC) with cross validation
# ======================================================================================================

# %%
from roc import plotROC

import matplotlib.pylab as pl

plotROC(lsvm_corr, X_lsvm_corr, y, skf, atlas, correlation, lsvm)
plotROC(lsvm_part, X_lsvm_part, y, skf, atlas, partial, lsvm)
plotROC(lsvm_tang, X_lsvm_tang, y, skf, atlas, tangent, lsvm)

# %% [markdown]
# =========================================================
# # Kernal SVM
# =========================================================

# %% [markdown]
# #### Kind = Correlation, Partial Correlation, Tangent
# ===========================================================================================================

# %%
# Correlation
from crossvalidation import CrossValidation

[X_ksvm_corr, ksvm_corr_scores] = CrossValidation(ksvm_corr, correlation, y, skf, time_series_dict)
[X_ksvm_part, ksvm_part_scores] = CrossValidation(ksvm_part, partial,     y, skf, time_series_dict)
[X_ksvm_tang, ksvm_tang_scores] = CrossValidation(ksvm_tang, tangent,     y, skf, time_series_dict)

# %%
from scores import getScores
[ksvm_corr_acc, ksvm_corr_sen, ksvm_corr_spe] = getScores(ksvm_corr_scores)
[ksvm_part_acc, ksvm_part_sen, ksvm_part_spe] = getScores(ksvm_part_scores)
[ksvm_tant_acc, ksvm_tang_sen, ksvm_tang_spe] = getScores(ksvm_tang_scores)

# %% [markdown]
# ##### Receiver Operating Characteristic (ROC) with cross validation
# ======================================================================================================

# %%
from roc import plotROC

import matplotlib.pylab as pl

plotROC(ksvm_corr, X_ksvm_corr, y, skf, atlas, correlation, ksvm)
plotROC(ksvm_part, X_ksvm_part, y, skf, atlas, partial, ksvm)
plotROC(ksvm_tang, X_ksvm_tang, y, skf, atlas, tangent, ksvm)

# %% [markdown]
# =========================================================
# # Random Forest
# =========================================================

# %% [markdown]
# #### Kind = Correlation, Partial Correlation, Tangent
# ===========================================================================================================

# %%
# Correlation
from crossvalidation import CrossValidation

[X_rf_corr, rf_corr_scores] = CrossValidation(rf_corr, correlation, y, skf, time_series_dict)
[X_rf_part, rf_part_scores] = CrossValidation(rf_part, partial,     y, skf, time_series_dict)
[X_rf_tang, rf_tang_scores] = CrossValidation(rf_tang, tangent,     y, skf, time_series_dict)

# %%
from scores import getScores
[rf_corr_acc, rf_corr_sen, rf_corr_spe] = getScores(rf_corr_scores)
[rf_part_acc, rf_part_sen, rf_part_spe] = getScores(rf_part_scores)
[rf_tant_acc, rf_tang_sen, rf_tang_spe] = getScores(rf_tang_scores)

# %% [markdown]
# ##### Receiver Operating Characteristic (ROC) with cross validation
# ======================================================================================================

# %%
from roc import plotROC

import matplotlib.pylab as pl

plotROC(rf_corr, X_rf_corr, y, skf, atlas, correlation, rf)
plotROC(rf_part, X_rf_part, y, skf, atlas, partial, rf)
plotROC(rf_tang, X_rf_tang, y, skf, atlas, tangent, rf)

# %% [markdown]
# =========================================================
# # Ada Boost
# =========================================================

# %% [markdown]
# #### Kind = Correlation, Partial Correlation, Tangent
# ===========================================================================================================

# %%
# Correlation
from crossvalidation import CrossValidation

[X_ab_corr, ab_corr_scores] = CrossValidation(ab_corr, correlation, y, skf, time_series_dict)
[X_ab_part, ab_part_scores] = CrossValidation(ab_part, partial,     y, skf, time_series_dict)
[X_ab_tang, ab_tang_scores] = CrossValidation(ab_tang, tangent,     y, skf, time_series_dict)

# %%
from scores import getScores
[ab_corr_acc, ab_corr_sen, ab_corr_spe] = getScores(ab_corr_scores)
[ab_part_acc, ab_part_sen, ab_part_spe] = getScores(ab_part_scores)
[ab_tant_acc, ab_tang_sen, ab_tang_spe] = getScores(ab_tang_scores)

# %% [markdown]
# ##### Receiver Operating Characteristic (ROC) with cross validation
# ======================================================================================================

# %%
from roc import plotROC

import matplotlib.pylab as pl

plotROC(ab_corr, X_ab_corr, y, skf, atlas, correlation, ab)
plotROC(ab_part, X_ab_part, y, skf, atlas, partial, ab)
plotROC(ab_tang, X_ab_tang, y, skf, atlas, tangent, ab)

# %% [markdown]
# # Summary Results

# %%
from IPython.display import HTML, display

test=[["","","Correlation"," "," ","Parital Corr",""," ","Tangent",""],
      
      ["Classifier","Sensitivity","Specificity", "Accuracy",\
       "Sensitivity","Specificity", "Accuracy",\
       "Sensitivity","Specificity", "Accuracy"],
      
      ["LR",lr_corr_sen,lr_corr_spe,lr_corr_acc,\
       lr_part_sen,lr_part_spe,lr_part_acc,\
       lr_tang_sen,lr_tang_spe,lr_tant_acc
      ],
      
      ["lSVM",lsvm_corr_sen,lsvm_corr_spe,lsvm_corr_acc,\
       lsvm_part_sen,lsvm_part_spe,lsvm_part_acc,\
       lsvm_tang_sen,lsvm_tang_spe,lsvm_tant_acc
      ],
      
      ["kSVM",ksvm_corr_sen,ksvm_corr_spe,ksvm_corr_acc,\
       ksvm_part_sen,ksvm_part_spe,ksvm_part_acc,\
       ksvm_tang_sen,ksvm_tang_spe,ksvm_tant_acc
      ],
      
      ["RF",rf_corr_sen,rf_corr_spe,rf_corr_acc,\
       rf_part_sen,rf_part_spe,rf_part_acc,\
       rf_tang_sen,rf_tang_spe,rf_tant_acc
      ], 
      
      ["AB",ab_corr_sen,ab_corr_spe,ab_corr_acc,\
       ab_part_sen,ab_part_spe,ab_part_acc,\
       ab_tang_sen,ab_tang_spe,ab_tant_acc
      ]
     ]

print("Test:")
print("===========================================================================================")
display(HTML(
   '<table><tr>{}</tr></table>'.format(
       '</tr><tr>'.join(
           '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row)) for row in test))
))
# Out:
# Test:
# ===========================================================================================
# <table><tr><td></td><td></td><td>Correlation</td><td> </td><td> </td><td>Parital Corr</td><td></td><td> </td><td>Tangent</td><td></td></tr><tr><td>Classifier</td><td>Sensitivity</td><td>Specificity</td><td>Accuracy</td><td>Sensitivity</td><td>Specificity</td><td>Accuracy</td><td>Sensitivity</td><td>Specificity</td><td>Accuracy</td></tr><tr><td>LR</td><td>52.88%</td><td>76.71%</td><td>65.67%</td><td>55.10%</td><td>68.79%</td><td>62.45%</td><td>62.29%</td><td>71.78%</td><td>67.40%</td></tr><tr><td>lSVM</td><td>60.31%</td><td>72.01%</td><td>66.59%</td><td>54.35%</td><td>68.16%</td><td>61.76%</td><td>37.49%</td><td>88.45%</td><td>64.88%</td></tr><tr><td>kSVM</td><td>63.55%</td><td>69.87%</td><td>66.94%</td><td>55.33%</td><td>60.03%</td><td>57.86%</td><td>60.31%</td><td>71.80%</td><td>66.48%</td></tr><tr><td>RF</td><td>41.96%</td><td>78.21%</td><td>61.43%</td><td>26.29%</td><td>84.82%</td><td>57.75%</td><td>33.76%</td><td>82.91%</td><td>60.16%</td></tr><tr><td>AB</td><td>54.11%</td><td>71.15%</td><td>63.26%</td><td>48.65%</td><td>60.25%</td><td>54.88%</td><td>52.13%</td><td>66.22%</td><td>59.70%</td></tr></table>
